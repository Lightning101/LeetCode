# %% [markdown]
# ### Comments
# ***This problem can be solved using a hash map***
#
# * The key lies in recreating the nodes and putting it in a hash map for the second iteration of the random pointers.
# * !Note make sure to keep the hash of the node itself as values can be repeated.
#
# ### Complexity:
#
# ***Time***: O(n)
#
# ***Space***: O(n)

# %%
"""
# Definition for a Node.
class Node:
    def __init__(self, x: int, next: 'Node' = None, random: 'Node' = None):
        self.val = int(x)
        self.next = next
        self.random = random
"""


class Solution:
    def copyRandomList(self, head: "Optional[Node]") -> "Optional[Node]":
        nodes = {}

        ans = Node(-1)
        temp = ans

        node = head
        while node:
            newNode = Node(node.val)
            temp.next = newNode
            temp = newNode
            nodes[node] = newNode
            node = node.next

        node = head
        while node:
            if node.random:
                nodes[node].random = nodes[node.random]
            node = node.next

        return ans.next

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Community References:
#
# * In this solution rather than doing two iterations one to make sure there is an entry in the map and then another to set the random pointers. We create the node and set to the map as we go and complete it in 1 iteration.
#
# ```
# class Solution:
#     def copyRandomList(self, head: "Optional[Node]") -> "Optional[Node]":
#         nodes = {}
#
#         ans = Node(-1)
#         temp = ans
#
#         node = head
#         while node:
#             newNode = nodes[node] if node in nodes else Node(node.val)
#             temp.next = newNode
#             temp = newNode
#             nodes[node] = newNode
#
#             if node.random:
#                 if not node.random in nodes:
#                     nodes[node.random] = Node(node.random.val)
#                 newNode.random = nodes[node.random]
#
#             node = node.next
#
#         return ans.next
# ```
