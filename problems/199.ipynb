# %% [markdown]
# ### Comments
# ***This problem can be solved using DFS***
#
#
# * The key lies in keeping track of the level we assume when we go left or right we go a level down.
# * Going right side first.
# * This allows us to reference with the ans array and to check if we have come across an answer for that level.
#
#
#
# **!Future me try rewrite it so that it uses the callback stack to keep the answer**
#
# ### Complexity:
#
# ***Time***: O(n)
#
# * We traverse all nodes.
#
# ***Space***: O(H)
#
# * Where H is the right height of the tree.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:

    def rightSideView(self, root, ans=None, level=1):
        if not root:
            return []
        if ans == None:
            ans = []

        if len(ans) < level:
            ans.append(root.val)

        self.rightSideView(root.right, ans, level + 1)
        self.rightSideView(root.left, ans, level + 1)
        return ans

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Community References:
