# %% [markdown]
# ### Comments
# ***This problem can be solved by using pointers***
#
# * We assign odd and even as head and head.next respectively.
# * Then we keep a node varaiable one infront of the chain. eg 1(odd) -> 2(even/evenHead) -> 3(node) -> 4 -> 5
# * We then assign to the even odd ptrs based on our count restructing the chain as we go.
# * One catch point being that if the chain ends on an odd we should set the even.next to node.
#
#
# ### Complexity:
#
# ***Time***:O(n)
#
# ***Space***: O(1)

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def oddEvenList(self, head):

        if(not head):return None

        evenHead = head.next

        odd = head
        even = head.next

        node =  even.next if even else None
        evenOdd = 1
        while(node):
            temp = node.next

            if(evenOdd):
                odd.next =node
                odd = node
            else:
                even.next = node
                even = node
            
            node = temp
            evenOdd = 1 - evenOdd
        if(not evenOdd):
            even.next = None
        odd.next = evenHead
        return head



s = Solution()



 

# Example 1:


# Input: head = [1,2,3,4,5]
# Output: [1,3,5,2,4]
values =  [2,1,3,5,6,4,7]
# values = [1,2,3,4,5]
head = ListNode(values[0])

node = head
for i in range(1,len(values)):
    newNode = ListNode(values[i])
    node.next = newNode
    node = newNode

print(s.oddEvenList(head))
# Example 2:


# Input: head = [2,1,3,5,6,4,7]
# Output: [2,3,6,7,1,5,4]
# print(s.oddEvenList([2,1,3,5,6,4,7]))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Community References:
#
# * A more advanced approach from the commuinty is to create both lists simultaneously.
#
# ```
# class Solution:
#     def oddEvenList(self, head):
#
#         if(not head):return None
#
#         evenHead = head.next
#         odd = head
#         even = head.next
#
#         while(even and even.next):
#             # iterate odd by one
#             odd.next = even.next
#             # setup for even
#             odd = odd.next
#
#             # iterate even by one
#             even.next = odd.next
#             # setup for odd
#             even = even.next
#
#         odd.next = evenHead
#         return head
#
# ```
