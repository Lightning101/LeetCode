# %% [markdown]
# ### Comments
# ***This problem can be solved with a 2 pointer approach***
#
# * The key is to walk the line and keep count of how many of the same element you have come across.
#
#
# ! I did a bit of shenanigans to avoid branching. Just so i dont look back and scratch my head.
#
# * Here in the reset when we change to a new element.
# ```
# c = (nums[i] == nums[p]) * c
#
# // Equvalent
#
# if(nums[i] != nums[p])
#     c = 0
# ```
#
# * Here in when we count how many of the same element.
# ```
# c += (c + 1) <= 2
#
# // Equvalent
#
# if(c+1 <=2):
#     c +=1
#
# ```
#
# ### Complexity:
#
# ***Time***:O(n)
#
# ***Space***: O(1)

# %%
class Solution:
    def removeDuplicates(self, nums: list[int]) -> int:
        p = 0
        c = 1
        for i in range(1, len(nums)):
            if nums[i] != nums[p] or c < 2:
                c = (nums[i] == nums[p]) * c
                nums[i], nums[p + 1] = nums[p + 1], nums[i]
                p += 1
            c += (c + 1) <= 2
        print(nums)
        return p +1


s = Solution()

# Example 1:

# Input: nums = [1,1,1,2,2,3]
# Output: 5, nums = [1,1,2,2,3,_]
# Explanation: Your function should return k = 5, with the first five elements of nums being 1, 1, 2, 2 and 3 respectively.
# It does not matter what you leave beyond the returned k (hence they are underscores).

print(s.removeDuplicates([1, 1, 1, 2, 2, 3]))
# Example 2:


# Input: nums = [0,0,1,1,1,1,2,3,3]
# Output: 7, nums = [0,0,1,1,2,3,3,_,_]
# Explanation: Your function should return k = 7, with the first seven elements of nums being 0, 0, 1, 1, 2, 3 and 3 respectively.
# It does not matter what you leave beyond the returned k (hence they are underscores).

print(s.removeDuplicates([0, 0, 1, 1, 1, 1, 2, 3, 3]))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Community References:
#
#
# * A far simpler version with the same 2 pointer intuition is:
#
#
#
# ```
# class Solution:
#     def removeDuplicates(self, nums: List[int]) -> int:
#         k = 2
#
#         for i in range(2, len(nums)):
#             if nums[i] != nums[k - 2]:
#                 nums[k] = nums[i]
#                 k += 1
#
#         return k
# ```
