# %% [markdown]
# ### Comments
# ***This problem can be solved using linked lists***
#
# * The key lies in keeping 2 lists one for larger and one for less. Then while iterating the list we assign to each.
# * Watch out for the case where the head itself is apart of the more list.
#
# ### Complexity:
#
# ***Time***: O(n)
#
# ***Space***: O(n)
#
# * As we keep 2 dummy lists but we only will have max n elements on it.

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def partition(self, head: Optional[ListNode], x: int) -> Optional[ListNode]:
        less = ListNode()
        more = ListNode()
        lessHead = less
        moreHead = more
        node = head

        while node:
            if node.val < x:
                less.next = node
                less = node
            else:
                more.next = node
                more = node
            node = node.next

        more.next = None
        less.next = moreHead.next
        return lessHead.next

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Community References:
